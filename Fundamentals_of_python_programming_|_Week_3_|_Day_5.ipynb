# %% [markdown]
# <a href="https://colab.research.google.com/github/mahamtaqi3-cloud/Python-for-Absolute-Beginners-Session/blob/main/Fundamentals_of_python_programming_%7C_Week_3_%7C_Day_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pythonic habits: list comprehensions and lambda functions

# %% [markdown]
# List comprehension is a concise way to create a new list from an existing iterable such as a list, range, or string.
#
# Basic syntax
# [expression for item in iterable]

# %% [markdown]
# Example 1: Create a list of squares
#
# Normal for loop:

# %%
squares = []

for i in range(1, 6):
    squares.append(i ** 2)

print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
#Using list comprehension:
squares = [i ** 2 for i in range(1, 6)]

print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
#Example Strings
names = ["Ali", "Sara", "Maham"]

uppercase = [name.upper() for name in names]

print(uppercase)
# Out:
# ['ALI', 'SARA', 'MAHAM']

# %% [markdown]
# **Function:** Function is a reusable block of code in python that performs a specific task. If you want to do one work again and again then we write that code in function and whenever necessary we call this function. In this way code becomes smaller, cleaner, and easy to maintain.
#
# *def → keyword to make function
#
# *function_name → name of function
#
# *parameters → input values (optional)
#
# *return → to give output (optional)

# %%
def greet():
    print("Hello, Maham!")

# %%
greet()
# Out:
# Hello, Maham!

# %% [markdown]
# **Function parameters and return values**
#
# ---
#
#
# Function Parameters and Return Values in Python are two of the most important concepts in programming.
#
# Parameters are variables listed inside the parentheses when you define a function. They allow you to pass information into the function.
#
# return
#
# Sometimes we don't want a function to just print something—we want it to give back a value so we can use it later.
#
# This is done using the return keyword.

# %%
def greet(name):
    print("Hello", name)

# %%
#Here:

#name is the parameter.
#The function is waiting for a value.

#When calling the function:

# %%
greet("Maham")
# Out:
# Hello Maham

# %%
def add(a, b):
    print(a + b)

# %%
add(10, 20)
# Out:
# 30

# %%
def function():
    return value

# %%
def add(a, b):
    return a + b

# %%
result = add(5, 3)

print(result)
# Out:
# 8

# %%
def add(a, b):
    return a + b

answer = add(4, 6)

print(answer * 2)
# Out:
# 20

# %% [markdown]
# Lambda Functions in Python
#
# A lambda function is a small, anonymous (nameless) function that can have any number of parameters but only one expression.
#
# It is useful when you need a simple function for a short period of time.
#
# Syntax:
#
# lambda parameters: expression
#
# lambda → Keyword used to create the function.
#
# Parameters → Inputs to the function.
#
# Expression → The calculation or operation to perform.
#
# The result of this expression is automatically returned.

# %%
#Lambda Function
square = lambda x: x * x

print(square(5))
# Out:
# 25

# %%
add = lambda a, b: a + b

print(add(10, 20))
# Out:
# 30

# %%
#Why Use Lambda Functions?

#Lambda functions are useful when you need a function only once and don't want to write a full def function.

#For example, sorting a list:

# %%
students = [("Ali", 80), ("Sara", 95), ("Ahmed", 70)]

students.sort(key=lambda student: student[1])

print(students)
# Out:
# [('Ahmed', 70), ('Ali', 80), ('Sara', 95)]

# %% [markdown]
# map(), filter(), reduce() in python:
#
# map(), filter(), and reduce() are higher-order functions in Python. They allow you to process collections (such as lists) efficiently, often with the help of lambda functions.

# %%
#map()
#Purpose
#map() applies a function to every element of an iterable (such as a list).

#Syntax
#map(function, iterable)
#function → the function to apply
#iterable → list, tuple, etc.

#Since map() returns a map object, you usually convert it into a list.
numbers = [1, 2, 3, 4, 5]

result = map(lambda element: element**2, numbers)

print(list(result))
# Out:
# [1, 4, 9, 16, 25]

# %%
#filter()
#Purpose

#filter() selects only those elements that satisfy a condition.

#Syntax
#filter(function, iterable)

#The function must return:

#True → keep the element
#False → discard the element

#Example 1: Keep only even numbers
numbers = [1,2,3,4,5,6,7,8]

even = filter(lambda x: x % 2 == 0, numbers)

print(list(even))
# Out:
# [2, 4, 6, 8]

# %%
#Example 2: Find students who passed

marks = [45, 82, 60, 35, 90]

passed = filter(lambda x: x >= 50, marks)

print(list(passed))
# Out:
# [82, 60, 90]

# %%
# reduce()
#Purpose

#reduce() combines all elements into a single value.

#Unlike map() and filter(), reduce() is part of the functools module.

#Import it
from functools import reduce

#Syntax
#reduce(function, iterable)
#The function takes two arguments:
lambda x, y: ...
#where:

#x = accumulated result
#y = next element

#Example 1: Sum all numbers
from functools import reduce

numbers = [1,2,3,4,5]

total = reduce(lambda x, y: x + y, numbers)

print(total)
# Out:
# 15

# %% [markdown]
# 1. Functions
# Exercise 1
#
# Write a function that prints "Hello, Python!"
#
# Exercise 2
#
# Write a function that prints your favorite programming language.
#
# 2. Function Parameters and Return Values
# Exercise 1
#
# Write a function that takes a number and returns its square.
#
# Exercise 2
#
# Write a function that accepts two numbers and returns their sum.
#
# 3. Lambda Functions
# Exercise 1
#
# Create a lambda function that doubles a number.
# Exercise 2
#
# Create a lambda function that multiplies two numbers.
#
# 4. map()
# Exercise 1
#
# Use map() to square every number in the list.
#
# 5. filter()
# Exercise 1
#
# Keep only even numbers.
#
# 6. reduce()
#
# Remember to import reduce.
# Exercise 1
#
# Find the sum of all numbers.

# %%
#Functions Exercise 1
#Write a function that prints "Hello, Python!"
def greet():
  print("Hello, Python!")

greet()
# Out:
# Hello, Python!

# %%
#Exercise 2

#Write a function that prints your favorite programming language.

def favorite_language():
  print("Python")
favorite_language()
# Out:
# Python

# %%
#Write a function that takes a number and returns its square.
def square(num):
  return num * num
result = square(6)
print(result)
# Out:
# 36

# %%
#Write a function that accepts two numbers and returns their sum.
def add(a, b):
  return a + b
print(add(10, 30))
# Out:
# 40

# %%
#Create a lambda function that doubles a number.
double = lambda x: x * 2
print(double(20))
# Out:
# 40

# %%
#Create a lambda function that multiplies two numbers.
multiply = lambda x, y: x * y
print(multiply(10, 20))
# Out:
# 200

# %%
#Use map() to square every number in the list.
numbers = [1, 2, 3, 4, 5, 6]
def square(x):
  return x * x
result = list(map(square, numbers))

print(result)
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
numbers = [1, 2, 3, 4, 5, 6]
result = []
for num in numbers:
  result.append(num * num)
print(result)
# Out:
# [1, 4, 9, 16, 25, 36]
